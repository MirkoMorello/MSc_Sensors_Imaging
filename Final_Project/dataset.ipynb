# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt


dataset = pd.read_csv('LTOA_GNDALT_0.01_SZA_27_AOT_0.01.csv').T

# %%
# print the first 5 rows of the dataset
print(dataset.head())
# Out:
#            0        1        2        3        4        5        6     \
# 650.03  650.070  650.110  650.150  650.200  650.240  650.280  650.320
# 68.652   61.115   67.939   54.709   68.858   68.991   68.033   67.315
# 58.354   51.952   57.756   46.512   58.544   58.663   57.851   57.245
# 54.528   48.548   53.974   43.467   54.714   54.828   54.070   53.506
# 52.818   47.027   52.284   42.108   53.004   53.116   52.383   51.838
#
#            7        8        9     ...     3609     3610     3611     3612  \
# 650.03  650.360  650.410  650.450  ...  849.330  849.400  849.470  849.550
# 68.652   65.668   68.249   68.457  ...   85.487   83.803   84.553   84.830
# 58.354   55.850   58.048   58.224  ...   85.495   83.811   84.560   84.836
# 54.528   52.206   54.262   54.427  ...   85.500   83.815   84.564   84.840
# 52.818   50.580   52.573   52.733  ...   85.504   83.819   84.567   84.843
#
#            3613     3614     3615     3616     3617     3618
# ...

# %%
dataset

# %%
# plot the dataset
# xlim = [0, 1000]
# ylim = [0, 1000]

plt.figure(figsize=(20,10))
plt.plot(dataset.iloc[400], label='LTOA', color='blue', linewidth=2, alpha=0.7)

plt.xlabel('Time')
plt.ylabel('Value')
plt.title('LTOA')
plt.legend()
plt.grid()

#plt.xlim(680, 780)

plt.show()
